# %% [markdown]
# <a href="https://colab.research.google.com/github/ArchanaSooraj/Archana-connect/blob/main/AMAZONE_Srapinng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
#no_pages = 2
def get_data(pageNo):  
   
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36',
    'referer': 'https://google.com',
    }
    r = requests.get('https://www.amazon.in/s?k=LG&i=electronics&rh=n%3A976419031%2Cn%3A1389401031%2Cn%3A1389432031%2Cn%3A1805560031%2Cp_98%3A10440597031&page='+str(pageNo)+'&qid=1640308697&ref=sr_pg_'+str(pageNo))
    
    print('https://www.amazon.in/s?k=LG&i=electronics&rh=n%3A976419031%2Cn%3A1389401031%2Cn%3A1389432031%2Cn%3A1805560031%2Cp_98%3A10440597031&page='+str(pageNo)+'&qid=1640308697&ref=sr_pg_'+str(pageNo))
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)
    #i = pageNo
    #print(i)
    alls = []
    for d in soup.findAll('div', attrs={'class':'s-card-container s-overflow-hidden s-include-content-margin s-latency-cf-section s-card-border'}):
        #print(d)
        name = d.find('span', attrs={'class':'a-size-medium a-color-base a-text-normal'})
        rating = d.find('div', attrs={'class' :'a-row a-size-small'})
        price = d.find('span', attrs={'class':'a-price-whole'})

        all1=[]

        if name is not None:
            #print(n[0]['alt'])
            all1.append(name.text)
        else:
            all1.append("unknown-product")

        if rating is not None:
            #print(rating.text)
            all1.append(rating.text)
        else:
            all1.append('-1')    

        if price is not None:
            #print(price.text)
            all1.append(price.text)
        else:
            all1.append('0')
        alls.append(all1) 
        #print(alls)
        #print(all1)
    #i = 1 + 1
    #print(i)
    return alls

# %%
no_pages = 4
results = []
for i in range(1, 5):
    print(i)
    results.append(get_data(i))
    print(results[i-1])
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['Name','Rating','Price'])
df
# Out:
# 1
# https://www.amazon.in/s?k=LG&i=electronics&rh=n%3A976419031%2Cn%3A1389401031%2Cn%3A1389432031%2Cn%3A1805560031%2Cp_98%3A10440597031&page=1&qid=1640308697&ref=sr_pg_1
# ...
